# %%
import pandas as pd
import numpy as np
from pylab import show, scatter, xlim, ylim
from random import randint

# %% [markdown]
# # Quiz
# ### Let R = 2.5 and x0 =0.2 and use Logistic Map to calculate x1,x2 until a fixed point is reached

# %%
def logisticMap(x ,r):
    cap = r * (x - x**2)
    return cap

# %%
logisticMap(.2,2.5)
# Out:
# 0.4

# %%
x = logisticMap(.2,2.5)

# %%
x
# Out:
# 0.4

# %%
print(np.linspace(.2,1,11,endpoint=False))
# Out:
# [0.2        0.27272727 0.34545455 0.41818182 0.49090909 0.56363636
#  0.63636364 0.70909091 0.78181818 0.85454545 0.92727273]

# %%
x_list = []
for i in np.linspace(.2,1,11,endpoint=False):
    x_list = logisticMap(i,2.5)
    scatter(i,x_list)

# %% [markdown]
# #### Then I found this! It makes a fractal
#
# https://www.reddit.com/r/learnpython/comments/zzh28/a_simple_python_implementation_of_the_logistic_map/

# %%
iter = 1000         # Number of iterations per point
seed = 0.2          # Seed value for x in (0, 1)
spacing = .0001     # Spacing between points on domain (r-axis)
res = 8             # Largest n-cycle visible

# %%
# Initialize r and x lists
rlist = []
xlist = []

def logisticmap(x, r):

    return x * r * (1 - x)

# Return nth iteration of logisticmap(x. r)
def iterate(n, x, r):

    for i in range(1,n):
        x = logisticmap(x, r)

    return x

# Generate list values -- iterate for each value of r
for r in [i * spacing for i in range(int(1/spacing),int(4/spacing))]:
   rlist.append(r) 
   xlist.append(iterate(randint(iter-res/2,iter+res/2), seed, r))

# %%
scatter(rlist, xlist, s = .01)
xlim(0.9, 4.1)
ylim(-0.1,1.1)
show()
